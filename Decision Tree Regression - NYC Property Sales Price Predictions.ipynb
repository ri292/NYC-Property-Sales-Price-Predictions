# %% [markdown]
# # NYC Property Sales Price Predictions

# %% [markdown]
# Note: We will add our problem statement and project description (target variable, features, etc.) here.

# %%
#These are the packages we are importing for our analysis.

import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
import math
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
# Out:
#      |████████████████████████████████| 993kB 4.7MB/s
#   Building wheel for PyDrive (setup.py) ... done

# %%
link = 'https://drive.google.com/open?id=147GTGRGGQIcmJKe9Zd--qej05HAoJoX8'
fluff, id = link.split('=')
print (id)
# Out:
# 147GTGRGGQIcmJKe9Zd--qej05HAoJoX8

# %%
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('nyc-rolling-sales.csv')  
df = pd.read_csv('nyc-rolling-sales.csv')

# %%
df
# Out:
#        Unnamed: 0  BOROUGH  ... SALE PRICE            SALE DATE
# 0               4        1  ...    6625000  2017-07-19 00:00:00
# 1               5        1  ...        -    2016-12-14 00:00:00
# 2               6        1  ...        -    2016-12-09 00:00:00
# 3               7        1  ...    3936272  2016-09-23 00:00:00
# 4               8        1  ...    8000000  2016-11-17 00:00:00
# 5               9        1  ...        -    2017-07-20 00:00:00
# 6              10        1  ...    3192840  2016-09-23 00:00:00
# 7              11        1  ...        -    2017-07-20 00:00:00
# 8              12        1  ...        -    2017-06-20 00:00:00
# 9              13        1  ...   16232000  2016-11-07 00:00:00
# 10             14        1  ...        -    2017-07-20 00:00:00
# 11             15        1  ...   10350000  2016-10-17 00:00:00
# 12             16        1  ...          1  2016-09-06 00:00:00
# 13             17        1  ...     499000  2017-03-10 00:00:00
# 14             18        1  ...         10  2017-04-28 00:00:00
# 15             19        1  ...     529500  2017-06-09 00:00:00
# 16             20        1  ...     423000  2017-07-14 00:00:00
# 17             21        1  ...     501000  2017-03-16 00:00:00
# 18             22        1  ...     450000  2016-09-01 00:00:00
# 19             23        1  ...     510000  2017-08-17 00:00:00
# 20             24        1  ...        -    2016-09-07 00:00:00
# 21             25        1  ...     350000  2017-08-30 00:00:00
# 22             26        1  ...   11900000  2017-06-21 00:00:00
# 23             27        1  ...   11900000  2017-06-21 00:00:00
# 24             28        1  ...     350000  2017-01-30 00:00:00
# 25             29        1  ...     404000  2017-07-07 00:00:00
# 26             30        1  ...     535000  2017-06-21 00:00:00
# 27             31        1  ...    1400000  2017-08-04 00:00:00
# 28             32        1  ...     866000  2017-01-09 00:00:00
# 29             33        1  ...     355000  2017-04-18 00:00:00
# ...           ...      ...  ...        ...                  ...
# 84518        8384        5  ...     875000  2016-09-05 00:00:00
# 84519        8385        5  ...     875000  2017-05-22 00:00:00
# 84520        8386        5  ...     840000  2016-12-07 00:00:00
# 84521        8387        5  ...     772500  2017-03-30 00:00:00
# 84522        8388        5  ...     740000  2017-01-04 00:00:00
# 84523        8389        5  ...        -    2017-03-17 00:00:00
# 84524        8390        5  ...        -    2017-07-06 00:00:00
# 84525        8391        5  ...        -    2016-10-14 00:00:00
# 84526        8392        5  ...     590000  2017-03-01 00:00:00
# 84527        8393        5  ...     580000  2017-04-26 00:00:00
# 84528        8394        5  ...     550000  2017-06-20 00:00:00
# 84529        8395        5  ...     545000  2016-11-16 00:00:00
# 84530        8396        5  ...     800000  2017-01-09 00:00:00
# 84531        8397        5  ...     642500  2017-06-22 00:00:00
# 84532        8398        5  ...     408092  2016-09-26 00:00:00
# 84533        8399        5  ...     600000  2017-02-27 00:00:00
# 84534        8400        5  ...     610000  2016-12-05 00:00:00
# 84535        8401        5  ...     645000  2017-08-04 00:00:00
# 84536        8402        5  ...     168000  2017-01-19 00:00:00
# 84537        8403        5  ...     625000  2016-10-18 00:00:00
# 84538        8404        5  ...        -    2017-06-30 00:00:00
# 84539        8405        5  ...        -    2016-12-30 00:00:00
# 84540        8406        5  ...     509000  2016-10-31 00:00:00
# 84541        8407        5  ...     648000  2016-12-07 00:00:00
# 84542        8408        5  ...        -    2016-12-01 00:00:00
# 84543        8409        5  ...     450000  2016-11-28 00:00:00
# 84544        8410        5  ...     550000  2017-04-21 00:00:00
# 84545        8411        5  ...     460000  2017-07-05 00:00:00
# 84546        8412        5  ...   11693337  2016-12-21 00:00:00
# 84547        8413        5  ...      69300  2016-10-27 00:00:00
#
# [84548 rows x 22 columns]

# %% [markdown]
# ## In the cells below we focus on cleaning up the data for our analysis.

# %%
df = df.drop(df.columns[0],axis = 1)
df.head()
# Out:
#    BOROUGH   NEIGHBORHOOD  ... SALE PRICE            SALE DATE
# 0        1  ALPHABET CITY  ...    6625000  2017-07-19 00:00:00
# 1        1  ALPHABET CITY  ...        -    2016-12-14 00:00:00
# 2        1  ALPHABET CITY  ...        -    2016-12-09 00:00:00
# 3        1  ALPHABET CITY  ...    3936272  2016-09-23 00:00:00
# 4        1  ALPHABET CITY  ...    8000000  2016-11-17 00:00:00
#
# [5 rows x 21 columns]

# %%
df.rename(columns={'BUILDING CLASS AT PRESENT': 'BUILDINGCLASSPRESENT', 'APARTMENT NUMBER': 'APARTMENTNUMBER', 'ZIP CODE': 'ZIPCODE', 'RESIDENTIAL UNITS': 'RESIDENTIALUNITS', 'COMMERCIAL UNITS': 'COMMERCIALUNITS', 'TOTAL UNITS': 'TOTALUNITS', 'LAND SQUARE FEET': 'LANDSQUAREFEET', 'GROSS SQUARE FEET': 'GROSSSQUAREFEET', 'YEAR BUILT': 'YEARBUILT', 'TAX CLASS AT TIME OF SALE': 'TAXCLASSTIMEOFSALE', 'BUILDING CLASS AT TIME OF SALE': 'BUILDINGCLASSTIMEOFSALE', 'SALE PRICE': 'SALEPRICE', 'SALE DATE': 'SALEDATE', 'BUILDING CLASS CATEGORY': 'BUILDINGCLASSCATEGORY','TAX CLASS AT PRESENT': 'TAXCLASSATPRESENT'}, inplace=True)

# %%
df["BUILDINGCLASSCATEGORYTRUNC"] = df["BUILDINGCLASSCATEGORY"].str[:2]
df.BUILDINGCLASSCATEGORYTRUNC = pd.to_numeric(df.BUILDINGCLASSCATEGORYTRUNC,errors='coerce')
df.head()
# Out:
#    BOROUGH   NEIGHBORHOOD  ...             SALEDATE BUILDINGCLASSCATEGORYTRUNC
# 0        1  ALPHABET CITY  ...  2017-07-19 00:00:00                          7
# 1        1  ALPHABET CITY  ...  2016-12-14 00:00:00                          7
# 2        1  ALPHABET CITY  ...  2016-12-09 00:00:00                          7
# 3        1  ALPHABET CITY  ...  2016-09-23 00:00:00                          7
# 4        1  ALPHABET CITY  ...  2016-11-17 00:00:00                          7
#
# [5 rows x 22 columns]

# %%
df = df[~(df['BUILDINGCLASSCATEGORYTRUNC'] > 20)]
df.shape
# Out:
# (78263, 22)

# %%
df = df[df.SALEPRICE != " -  "]
df.shape
# Out:
# (65732, 22)

# %%
df.SALEPRICE = pd.to_numeric(df.SALEPRICE,errors='coerce')
df = df[~(df['SALEPRICE'] < 10000)]
df.shape
# Out:
# (55985, 22)

# %%
df['AVGPRICEBOROUGH'] = df.groupby([pd.Grouper(key='BOROUGH')])['SALEPRICE'].transform('mean')
df['AVGPRICEZIPCODE'] = df.groupby([pd.Grouper(key='ZIPCODE')])['SALEPRICE'].transform('mean')
df['AVGPRICEBLOCK'] = df.groupby([pd.Grouper(key='BLOCK')])['SALEPRICE'].transform('mean')

# %%
df['LN_PRICE'] = np.log(df['SALEPRICE'])
df
# Out:
#        BOROUGH   NEIGHBORHOOD  ... BUILDINGCLASSCATEGORYTRUNC   LN_PRICE
# 0            1  ALPHABET CITY  ...                          7  15.706361
# 3            1  ALPHABET CITY  ...                          7  15.185745
# 4            1  ALPHABET CITY  ...                          7  15.894952
# 6            1  ALPHABET CITY  ...                          7  14.976421
# 9            1  ALPHABET CITY  ...                          8  16.602495
# 11           1  ALPHABET CITY  ...                          8  16.152497
# 13           1  ALPHABET CITY  ...                          9  13.120361
# 15           1  ALPHABET CITY  ...                          9  13.179688
# 16           1  ALPHABET CITY  ...                          9  12.955127
# 17           1  ALPHABET CITY  ...                          9  13.124361
# 18           1  ALPHABET CITY  ...                          9  13.017003
# 19           1  ALPHABET CITY  ...                          9  13.142166
# 21           1  ALPHABET CITY  ...                          9  12.765688
# 22           1  ALPHABET CITY  ...                          9  16.292049
# 23           1  ALPHABET CITY  ...                          9  16.292049
# 24           1  ALPHABET CITY  ...                          9  12.765688
# 25           1  ALPHABET CITY  ...                          9  12.909170
# 26           1  ALPHABET CITY  ...                          9  13.190022
# 27           1  ALPHABET CITY  ...                          9  14.151983
# 28           1  ALPHABET CITY  ...                          9  13.671640
# 29           1  ALPHABET CITY  ...                          9  12.779873
# 31           1  ALPHABET CITY  ...                          9  13.598598
# 32           1  ALPHABET CITY  ...                          9  13.071070
# 33           1  ALPHABET CITY  ...                          9  13.017003
# 34           1  ALPHABET CITY  ...                          9  13.017003
# 35           1  ALPHABET CITY  ...                          9  13.604790
# 37           1  ALPHABET CITY  ...                          9  12.611538
# 38           1  ALPHABET CITY  ...                          9  12.611538
# 39           1  ALPHABET CITY  ...                          9  13.269058
# 40           1  ALPHABET CITY  ...                          9  14.220976
# ...        ...            ...  ...                        ...        ...
# 84503        5        WOODROW  ...                          2  13.924365
# 84508        5        WOODROW  ...                          2  13.552846
# 84510        5        WOODROW  ...                          2  13.296317
# 84511        5        WOODROW  ...                          2  13.005830
# 84512        5        WOODROW  ...                          2  13.573439
# 84514        5        WOODROW  ...                          2  13.253392
# 84516        5        WOODROW  ...                          2  13.489780
# 84517        5        WOODROW  ...                          2  13.208541
# 84518        5        WOODROW  ...                          2  13.681979
# 84519        5        WOODROW  ...                          2  13.681979
# 84520        5        WOODROW  ...                          2  13.641157
# 84521        5        WOODROW  ...                          2  13.557387
# 84522        5        WOODROW  ...                          2  13.514405
# 84526        5        WOODROW  ...                          2  13.287878
# 84527        5        WOODROW  ...                          2  13.270783
# 84528        5        WOODROW  ...                          2  13.217674
# 84529        5        WOODROW  ...                          2  13.208541
# 84530        5        WOODROW  ...                          2  13.592367
# 84531        5        WOODROW  ...                          2  13.373122
# 84532        5        WOODROW  ...                          2  12.919248
# 84533        5        WOODROW  ...                          2  13.304685
# 84534        5        WOODROW  ...                          2  13.321214
# 84535        5        WOODROW  ...                          2  13.377006
# 84536        5        WOODROW  ...                          2  12.031719
# 84537        5        WOODROW  ...                          2  13.345507
# 84540        5        WOODROW  ...                          2  13.140203
# 84541        5        WOODROW  ...                          2  13.381646
# 84543        5        WOODROW  ...                          2  13.017003
# 84544        5        WOODROW  ...                          2  13.217674
# 84545        5        WOODROW  ...                          2  13.038982
#
# [55985 rows x 23 columns]

# %% [markdown]
# ## Here we converted the variables for each feature into columns with binary variables using get_dummies.

# %%
df = pd.get_dummies(df, columns=['ZIPCODE','BOROUGH','NEIGHBORHOOD','BUILDINGCLASSCATEGORY','TAXCLASSATPRESENT','BUILDINGCLASSPRESENT','YEARBUILT','TAXCLASSTIMEOFSALE','BUILDINGCLASSTIMEOFSALE'])
df.head()
# Out:
#    BLOCK  LOT  ... BUILDINGCLASSTIMEOFSALE_V3 BUILDINGCLASSTIMEOFSALE_Z0
# 0    392    6  ...                          0                          0
# 3    402   21  ...                          0                          0
# 4    404   55  ...                          0                          0
# 6    406   32  ...                          0                          0
# 9    387  153  ...                          0                          0
#
# [5 rows x 743 columns]

# %% [markdown]
# ## Decision Tree Regressor Model

# %%
X = df[df.columns.difference(['BLOCK', 'LOT', 'EASE-MENT', 'ADDRESS', 'APARTMENTNUMBER', 'SALEPRICE', 'SALEDATE', 'BUILDINGCLASSCATEGORYTRUNC', 'LANDSQUAREFEET', 'GROSSSQUAREFEET'])]
Y = df['SALEPRICE']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2, random_state=42)

# %%
#https://www.python-course.eu/Regression_Trees.php
#Import the regression tree model
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

#Parametrize the model
#We will use the mean squared error == variance as spliting criteria and set the minimum number of instances per leaf = 5

regression_model = DecisionTreeRegressor(criterion="mse",min_samples_leaf=5)

#Fit the model
regression_model.fit(X_train,Y_train)

#Predict unseen query instances
predicted = regression_model.predict(X_test)

#Compute and plot the RMSE
RMSE = np.sqrt(np.sum(((Y_test-predicted)**2)/len(Y_test)))
RMSE
# Out:
# 154057.35729479854

# %%
#Fit the model
regression_model.fit(X_train,Y_train)

#Predict unseen query instances
predicted = regression_model.predict(X_test)

#Compute and plot the RMSE
RMSE = np.sqrt(np.sum(((Y_test-predicted)**2)/len(Y_test)))
RMSE
# Out:
# 154057.34848726765

# %%
fig = plt.figure()
ax0 = fig.add_subplot(111) 
RMSE_train = []
RMSE_test = []
for i in range(1,100):
    #Paramterize the model and let i be the number of minimum instances per leaf node
    regression_model = DecisionTreeRegressor(criterion="mse",min_samples_leaf=i)   
    #Train the model
    regression_model.fit(X_train,Y_train)
    #Predict query instances
    predicted_train = regression_model.predict(X_train)
    predicted_test = regression_model.predict(X_test)
    #Calculate and append the RMSEs
    RMSE_train.append(np.sqrt(np.sum(((Y_train-predicted_train)**2)/len(Y_train))))
    RMSE_test.append(np.sqrt(np.sum(((Y_test-predicted_test)**2)/len(Y_test))))
   
ax0.plot(range(1,100),RMSE_test,label='Test_Data')
ax0.plot(range(1,100),RMSE_train,label='Train_Data')
ax0.legend()
ax0.set_title('RMSE with respect to the minumum number of instances per node')
ax0.set_xlabel('#Instances')
ax0.set_ylabel('RMSE')
plt.show()

# %%
errors = abs(predicted - Y_test)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'dollars.')

# %%
mape = 100 * (errors / Y_test)
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 99.96 %.

# %%
regression_model = DecisionTreeRegressor(criterion="mse",max_depth=7)

#Fit the model
regression_model.fit(X_train,Y_train)

#Predict unseen query instances
predicted = regression_model.predict(X_test)

#Compute and plot the RMSE
RMSE = np.sqrt(np.sum(((Y_test-predicted)**2)/len(Y_test)))
RMSE
# Out:
# 165954.73056467815

# %%
errors = abs(predicted - Y_test)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'dollars.')
# Out:
# Mean Absolute Error: 57360.66 dollars.

# %%
mape = 100 * (errors / Y_test)
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 85.74 %.

# %%
X = df[df.columns.difference(['BLOCK', 'LOT', 'EASE-MENT', 'ADDRESS', 'APARTMENTNUMBER', 'SALEPRICE', 'SALEDATE', 'BUILDINGCLASSCATEGORYTRUNC', 'LANDSQUAREFEET', 'GROSSSQUAREFEET', 'AVGPRICEBOROUGH', 'AVGPRICEZIPCODE', 'AVGPRICEBLOCK', 'LN_PRICE'])]
Y = df['SALEPRICE']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2, random_state=42)


regression_model = DecisionTreeRegressor(criterion="mse",max_depth=5)

#Fit the model
regression_model.fit(X_train,Y_train)

#Predict unseen query instances
predicted = regression_model.predict(X_test)

# %%
errors = abs(predicted - Y_test)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'dollars.')
# Out:
# Mean Absolute Error: 799413.95 dollars.

# %%
mape = 100 * (errors / Y_test)
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: -38.21 %.

# %%
X = df[df.columns.difference(['BLOCK', 'LOT', 'EASE-MENT', 'ADDRESS', 'APARTMENTNUMBER', 'SALEPRICE', 'SALEDATE', 'BUILDINGCLASSCATEGORYTRUNC', 'LANDSQUAREFEET', 'GROSSSQUAREFEET', 'AVGPRICEZIPCODE', 'AVGPRICEBLOCK', 'LN_PRICE'])]
Y = df['SALEPRICE']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2, random_state=42)


regression_model = DecisionTreeRegressor(criterion="mse",max_depth=5)

#Fit the model
regression_model.fit(X_train,Y_train)

#Predict unseen query instances
predicted = regression_model.predict(X_test)

# %%
errors = abs(predicted - Y_test)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'dollars.')
# Out:
# Mean Absolute Error: 799413.95 dollars.

# %%
mape = 100 * (errors / Y_test)
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: -38.21 %.

# %%
fig = plt.figure()
ax0 = fig.add_subplot(111) 
MAE_train = []
MAE_test = []
for i in range(1,10):
    #Paramterize the model and let i be the number of minimum instances per leaf node
    regression_model = DecisionTreeRegressor(criterion="mse",max_depth=i)   
    #Train the model
    regression_model.fit(X_train,Y_train)
    #Predict query instances
    predicted_train = regression_model.predict(X_train)
    predicted_test = regression_model.predict(X_test)
    #Calculate and append the MAEs
    errors_train = abs(predicted_train - Y_train)
    errors_test = abs(predicted_test - Y_test)
    MAE_train.append(round(np.mean(errors_train), 2))
    MAE_test.append(round(np.mean(errors_test), 2))
   
ax0.plot(range(1,10),MAE_test,label='Test_Data')
ax0.plot(range(1,10),MAE_train,label='Train_Data')
ax0.legend()
ax0.set_title('MAE with respect to the minumum depth')
ax0.set_xlabel('#Depth')
ax0.set_ylabel('MAE')
plt.show()

# %%
X = df[df.columns.difference(['BLOCK', 'LOT', 'EASE-MENT', 'ADDRESS', 'APARTMENTNUMBER', 'SALEPRICE', 'SALEDATE', 'BUILDINGCLASSCATEGORYTRUNC', 'LANDSQUAREFEET', 'GROSSSQUAREFEET', 'AVGPRICEBOROUGH', 'AVGPRICEZIPCODE', 'AVGPRICEBLOCK'])]
Y = df['SALEPRICE']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2, random_state=42)


regression_model = DecisionTreeRegressor(criterion="mse",max_depth=5)

#Fit the model
regression_model.fit(X_train,Y_train)

#Predict unseen query instances
predicted = regression_model.predict(X_test)

# %%
errors = abs(predicted - Y_test)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'dollars.')
# Out:
# Mean Absolute Error: 218194.39 dollars.

# %%
mape = 100 * (errors / Y_test)
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 47.62 %.

# %%
X = df[df.columns.difference(['BLOCK', 'LOT', 'EASE-MENT', 'ADDRESS', 'APARTMENTNUMBER', 'SALEPRICE', 'SALEDATE', 'BUILDINGCLASSCATEGORYTRUNC', 'LANDSQUAREFEET', 'GROSSSQUAREFEET', 'AVGPRICEBOROUGH', 'AVGPRICEZIPCODE', 'AVGPRICEBLOCK'])]
Y = df['SALEPRICE']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2, random_state=42)


regression_model = DecisionTreeRegressor(criterion="mse",max_depth=7)

#Fit the model
regression_model.fit(X_train,Y_train)

#Predict unseen query instances
predicted = regression_model.predict(X_test)

# %%
errors = abs(predicted - Y_test)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'dollars.')
# Out:
# Mean Absolute Error: 57234.65 dollars.

# %%
mape = 100 * (errors / Y_test)
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 85.74 %.

# %%
X = df[df.columns.difference(['BLOCK', 'LOT', 'EASE-MENT', 'ADDRESS', 'APARTMENTNUMBER', 'SALEPRICE', 'SALEDATE', 'BUILDINGCLASSCATEGORYTRUNC', 'LANDSQUAREFEET', 'GROSSSQUAREFEET', 'AVGPRICEBOROUGH', 'AVGPRICEZIPCODE', 'AVGPRICEBLOCK'])]
Y = df['SALEPRICE']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2, random_state=42)


regression_model = DecisionTreeRegressor(criterion="mse",max_depth=6)

#Fit the model
regression_model.fit(X_train,Y_train)

#Predict unseen query instances
predicted = regression_model.predict(X_test)

# %%
errors = abs(predicted - Y_test)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'dollars.')
# Out:
# Mean Absolute Error: 110581.8 dollars.

# %%
mape = 100 * (errors / Y_test)
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 72.71 %.
